# %% [markdown]
# <a href="https://colab.research.google.com/github/MahdiZakipour/Recent-General-Project/blob/main/Health_Costs_Calculator_(Linear_Regression)_General_Training.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# In this challenge, we will predict healthcare costs using a regression algorithm.
#
# The dataset contains information about different people including their healthcare costs.
#
# ### INSTRUCTIONS to Pass the Challenge:
# > Make sure to convert categorical data to numbers. The `train_dataset` to `test_dataset` is 80-20%.
#
# > `pop` off the "expenses" column from these datasets to create new datasets called `train_labels` and `test_labels`.
#
# > To pass the challenge, `model.evaluate` must return a Mean Absolute Error (`MSE`) under 3500.

# %%
# Import libraries. You may or may not use all of these.
# !pip install -q git+https://github.com/tensorflow/docs
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# The code inside the "try block" will execute when there is no error in the program. Whereas the code inside the "try block" will execute whenever the program encounters some error in the preceding try block.
try:
  # %tensorflow_version only exists in Colab.
  # %tensorflow_version 2.x
except Exception:
  pass

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import tensorflow_docs as tfdocs
import tensorflow_docs.plots
import tensorflow_docs.modeling

# %%
## Reading the data
# The free utility tool used to download files from the internet.
# Good for slow/unstable connections.
# !wget https://cdn.freecodecamp.org/project-data/health-costs/insurance.csv

dataset = pd.read_csv('insurance.csv')

from google.colab import data_table
data_table.enable_dataframe_formatter()

dataset
# Out:
#       age     sex   bmi  children smoker     region  expenses
# 0      19  female  27.9         0    yes  southwest  16884.92
# 1      18    male  33.8         1     no  southeast   1725.55
# 2      28    male  33.0         3     no  southeast   4449.46
# 3      33    male  22.7         0     no  northwest  21984.47
# 4      32    male  28.9         0     no  northwest   3866.86
# ...   ...     ...   ...       ...    ...        ...       ...
# 1333   50    male  31.0         3     no  northwest  10600.55
# 1334   18  female  31.9         0     no  northeast   2205.98
# 1335   18  female  36.9         0     no  southeast   1629.83
# 1336   21  female  25.8         0     no  southwest   2007.95
# 1337   61  female  29.1         0    yes  northwest  29141.36
#
# [1338 rows x 7 columns]

# %%
# RUN THIS CELL TO TEST YOUR MODEL. DO NOT MODIFY CONTENTS.
# Test model by checking how well the model generalizes using the test set.
loss, mae, mse = model.evaluate(test_dataset, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} expenses".format(mae))

if mae < 3500:
  print("You passed the challenge. Great job!")
else:
  print("The Mean Abs Error must be less than 3500. Keep trying.")

# Plot predictions.
test_predictions = model.predict(test_dataset).flatten()

a = plt.axes(aspect='equal')
plt.scatter(test_labels, test_predictions)
plt.xlabel('True values (expenses)')
plt.ylabel('Predictions (expenses)')
lims = [0, 50000]
plt.xlim(lims)
plt.ylim(lims)
_ = plt.plot(lims,lims)
